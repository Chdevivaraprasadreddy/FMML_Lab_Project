# %% [markdown]
# <a href="https://colab.research.google.com/github/Chdevivaraprasadreddy/FMML_Lab_Project/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-04-05 15:54:59--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   101MB/s    in 0.7s
#
# 2024-04-05 15:55:00 (101 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 6221   1609.07574v4  We study the pricing problem faced by a firm t...  stat
# 6674   1705.01708v2  Maximizing the area under the receiver operati...  stat
# 13184  1802.01223v1  We study the impact of regularization for lear...    cs
# 8483   1611.06624v3  In this paper, we propose a generative model, ...    cs
# 10511   1205.2632v1  Compressed Counting (CC) [22] was recently pro...    cs
# ...             ...                                                ...   ...
# 40564   1308.1066v1  Adaptive trials are now mainstream science. Re...  stat
# 40279  1803.02057v1  Accurate localization of other traffic partici...    cs
# 17573  1712.03665v1  The task of event extraction has long been inv...    cs
# 37980   0909.5026v2  We propose a new optimization algorithm for Mu...  stat
# 22172  1506.04725v1  We propose a class of nonparametric two-sample...  stat
#
#                                                    title  year  \
# 6221                  Dynamic Pricing in High-dimensions  2016
# 6674   Semi-Supervised AUC Optimization based on Posi...  2017
# 13184  Learning Compact Neural Networks with Regulari...  2018
# 8483   Temporal Generative Adversarial Nets with Sing...  2016
# 10511                      Improving Compressed Counting  2012
# ...                                                  ...   ...
# 40564  Theoretical Issues for Global Cumulative Treat...  2013
# 40279  The Earth ain't Flat: Monocular Reconstruction...  2018
# 17573  Scale Up Event Extraction Learning via Automat...  2017
# 37980                                           SpicyMKL  2009
# 22172  Fast Two-Sample Testing with Analytic Represen...  2015
#
#                                                 keywords
# 6221   [described, customers, customers, independentl...
# 6674   [maximizing, operating, characteristic, imbala...
# 13184  [regularization, improving, generalization, pe...
# 8483   [generative, generative, adversarial, represen...
# 10511  [compressed, estimating, frequency, estimating...
# ...                                                  ...
# 40564  [mainstream, researchers, conclusion, proposin...
# 40279  [localization, participants, autonomous, combi...
# 17573  [extraction, investigated, supervised, instanc...
# 37980  [optimization, algorithm, applicable, function...
# 22172  [nonparametric, distances, functions, represen...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 6221     [described, customers, customers, independentl...
# 6674     [maximizing, operating, characteristic, imbala...
# 13184    [regularization, improving, generalization, pe...
# 8483     [generative, generative, adversarial, represen...
# 10511    [compressed, estimating, frequency, estimating...
#                                ...
# 15501    [technology, dependency, strengths, transition...
# 17603    [investigate, facilitate, distribution, phonol...
# 19371    [proceedings, conference, uncertainty, artific...
# 21062    [approaches, structuring, functions, literatur...
# 7382     [exploration, exploitation, concerned, maximis...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8812 words.
# Out of those 4605 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="c8eb60c6-249f-4273-80d4-99d5c7efb473" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c8eb60c6-249f-4273-80d4-99d5c7efb473")) {                    Plotly.newPlot(                        "c8eb60c6-249f-4273-80d4-99d5c7efb473",                        [{"x":["described","dimensional","decisions","structured","independently","marketplaces","maximizing","according","objective","parameters","structure","purchasing","logarithmic","motivated","specifically","customers","regularized","algorithm","characteristics","dimensions","numerical","furthermore","leverages","clairvoyant","likelihood","prevalence","supervised","usefulness","scenarios","experiments","imbalanced","performance","developed","classification","demonstrate","combining","assumptions","practical","distributional","optimization","restrictive","satisfied","generalization","contribute","operating","characteristic","improving","unlabeled","theoretically","constraints","providing","dimension","activation","convergence","complexity","rademacher","efficient","conditioned","algorithms","beneficial","constraint","layerwise","introduce","regularization","properties","representation","effectiveness","consisting","wasserstein","experimental","deconvolutional","generators","adversarial","variables","different","transforms","instability","generative","corresponds","generator","generating","detection","monitoring","approximated","improvement","estimation","estimating","considerably","frequency","important","compressed","substantial","statistically","functions","uncertainty","multivariate","condition","continuous","generated","applications","necessary","discovery","identified","comparisons","particular","bivariate","conventional","causality","identifiability","artificial","sufficient","situations","incrementally","conditions","deformation","framework","efficiency","advantage","alignment","incremental","approaches","alleviate","evaluated","regressors","unconstrained","regression","challenging","personalized","configurations","investigation","crossover","application","distribution","presented","presenting","computational","operators","influences","combinatorial","effective","describes","including","multitask","formalized","available","applicable","improvements","augmentation","complementary","attention","methodology","increases","predictors","distributed","potential","electricity","representative","irregular","unreliable","industrial","significant","commercial","covariate","imbalance","reduction","affective","embeddings","accelerate","meaningful","representations","leveraged","propagation","classifier","expansion","reproducible","compatible","orientation","classifiers","automatically","specialized","embedding","performed","geometric","hyperparameter","algebraic","combination","naturally","nonlinear","appealing","recurrent","themselves","directional","convexity","accelerates","composite","stochastic","techniques","knowledge","stationary","iterations"],"y":[69,184,68,107,38,1,30,107,182,237,354,2,16,59,165,13,33,826,67,46,65,178,32,0,81,2,197,29,79,625,8,900,194,490,566,120,62,137,21,321,10,10,123,31,20,29,113,39,34,155,95,60,29,121,226,4,382,20,606,27,110,2,324,78,213,328,225,52,8,376,4,10,116,106,703,18,7,138,29,28,85,337,31,12,138,194,64,35,57,364,23,47,22,241,64,18,45,117,175,441,65,63,42,32,240,0,92,12,3,124,75,57,9,144,13,523,164,92,49,31,414,26,129,4,28,116,257,18,16,32,12,247,220,186,19,302,51,11,38,255,101,229,13,5,317,56,130,21,42,171,72,52,16,111,153,3,37,7,17,27,238,27,3,11,100,8,82,17,51,218,13,80,156,19,4,12,31,108,174,22,111,121,71,15,18,136,60,65,14,133,24,24,9,5,10,119,379,376,24,15],"type":"bar"},{"x":["described","dimensional","decisions","structured","independently ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4605,), (4605, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8291666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Deep</span> <span style='background-color:rgba(0, 255, 0, 0.5604395604395604);'>Convolutional</span> <span style=''>Neural</span> <span style=''>Network</span> <span style=''>Features</span> <span style=''>and</span> <span style=''>the</span> <span style=''>Original</span> <span style=''>Image</span> <br/><br/><span style=''>Face</span> <span style='background-color:rgba(0, 255, 0, 0.6244343891402715);'>recognition</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>based</span> <span style=''>on</span> <span style=''>deep</span> <span style='background-color:rgba(0, 255, 0, 0.5604395604395604);'>convolutional</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>(DCNNs)</span> <span style=''>have</span> <span style=''>made</span> <span style=''>progress</span> <span style=''>on</span> <span style=''>the</span> <span style=''>task</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.7142857142857142);'>recognizing</span> <span style=''>faces</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.47368421052631576);'>unconstrained</span> <span style=''>viewing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditions</span> <span style=''>These</span> <span style=''>networks</span> <span style=''>operate</span> <span style=''>with</span> <span style=''>compact</span> <span style=''>feature</span> <span style=''>based</span> <span style=''>face</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>representations</span> <span style=''>derived</span> <span style=''>from</span> <span style=''>learning</span> <span style=''>a</span> <span style=''>very</span> <span style=''>large</span> <span style=''>number</span> <span style=''>of</span> <span style=''>face</span> <span style=''>images</span> <span style=''>While</span> <span style=''>the</span> <span style=''>learned</span> <span style=''>features</span> <span style=''>produced</span> <span style=''>by</span> <span style=''>DCNNs</span> <span style=''>can</span> <span style=''>be</span> <span style=''>highly</span> <span style=''>robust</span> <span style=''>to</span> <span style=''>changes</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.5555555555555556);'>viewpoint</span> <span style='background-color:rgba(0, 255, 0, 0.9534883720930233);'>illumination</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.945945945945946);'>appearance</span> <span style=''>little</span> <span style=''>is</span> <span style=''>known</span> <span style=''>about</span> <span style=''>the</span> <span style=''>nature</span> <span style=''>of</span> <span style=''>the</span> <span style=''>face</span> <span style=''>code</span> <span style=''>that</span> <span style=''>emerges</span> <span style=''>at</span> <span style=''>the</span> <span style=''>top</span> <span style=''>level</span> <span style=''>of</span> <span style=''>such</span> <span style=''>networks</span> <span style=''>We</span> <span style=''>analyzed</span> <span style=''>the</span> <span style=''>DCNN</span> <span style=''>features</span> <span style=''>produced</span> <span style=''>by</span> <span style=''>two</span> <span style=''>face</span> <span style='background-color:rgba(0, 255, 0, 0.6244343891402715);'>recognition</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>In</span> <span style=''>the</span> <span style=''>first</span> <span style=''>set</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>experiments</span> <span style=''>we</span> <span style=''>used</span> <span style=''>the</span> <span style=''>top</span> <span style=''>level</span> <span style=''>features</span> <span style=''>from</span> <span style=''>the</span> <span style=''>DCNNs</span> <span style=''>as</span> <span style=''>input</span> <span style=''>into</span> <span  ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Bayesian</span> <span style=''>Model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Selection</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Stochastic</span> <span style=''>Block</span> <span style=''>Models</span> <br/><br/><span style=''>A</span> <span style=''>central</span> <span style=''>problem</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>analyzing</span> <span style=''>networks</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>partitioning</span> <span style=''>them</span> <span style=''>into</span> <span style=''>modules</span> <span style=''>or</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>communities</span> <span style=''>One</span> <span style=''>of</span> <span style=''>the</span> <span style=''>best</span> <span style=''>tools</span> <span style=''>for</span> <span style=''>this</span> <span style=''>is</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style=''>block</span> <span style=''>model</span> <span style=''>which</span> <span style=''>clusters</span> <span style=''>vertices</span> <span style=''>into</span> <span style=''>blocks</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistically</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>homogeneous</span> <span style=''>pattern</span> <span style=''>of</span> <span style=''>links</span> <span style=''>Despite</span> <span style=''>its</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>flexibility</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>popularity</span> <span style=''>there</span> <span style=''>has</span> <span style=''>been</span> <span style=''>a</span> <span style=''>lack</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>principled</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>criteria</span> <span style=''>for</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style=''>block</span> <span style=''>model</span> <span style=''>Here</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>Bayesian</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>for</span> <span style=''>choosing</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>blocks</span> <span style=''>as</span> <span style=''>well</span> <span style=''>as</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>comparing</span> <span style=''>it</span> <span style=''>to</span> <span style=''>the</span> <span style=''>more</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>elaborate</span> <span style=''>degree</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>corrected</span> <span style=''>block</span> <span style=''>models</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>ultimately</span> <span style=''>leading</span> <span style=''>to</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>universal</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>capable</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>comparing</span> <span style=''>multiple</span> <span style=''>modeling</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>combinations</span> <span style=''>We</span> <span style=''>will</span> <span style=''>also</span> <span style='background-color:rgba(255, 0, 0, ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Exactly</span> <span style=''>Robust</span> <span style=''>Kernel</span> <span style='background-color:rgba(255, 0, 0, 0.5);'>Principal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Component</span> <span style=''>Analysis</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>method</span> <span style=''>called</span> <span style=''>robust</span> <span style=''>kernel</span> <span style='background-color:rgba(255, 0, 0, 0.5);'>principal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>component</span> <span style=''>analysis</span> <span style=''>(RKPCA)</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>decompose</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.34736842105263166);'>partially</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>corrupted</span> <span style=''>matrix</span> <span style=''>as</span> <span style=''>a</span> <span style=''>sparse</span> <span style=''>matrix</span> <span style=''>plus</span> <span style=''>a</span> <span style=''>high</span> <span style=''>or</span> <span style=''>full</span> <span style=''>rank</span> <span style=''>matrix</span> <span style=''>whose</span> <span style=''>columns</span> <span style=''>are</span> <span style=''>drawn</span> <span style=''>from</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>nonlinear</span> <span style=''>low</span> <span style='background-color:rgba(255, 0, 0, 0.34751773049645385);'>dimensional</span> <span style=''>latent</span> <span style=''>variable</span> <span style=''>model</span> <span style=''>RKPCA</span> <span style=''>can</span> <span style=''>be</span> <span style=''>applied</span> <span style=''>to</span> <span style=''>many</span> <span style=''>problems</span> <span style=''>such</span> <span style=''>as</span> <span style=''>noise</span> <span style=''>removal</span> <span style=''>and</span> <span style=''>subspace</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>clustering</span> <span style=''>and</span> <span style=''>is</span> <span style=''>so</span> <span style=''>far</span> <span style=''>the</span> <span style=''>only</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>unsupervised</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>nonlinear</span> <span style=''>method</span> <span style=''>robust</span> <span style=''>to</span> <span style=''>sparse</span> <span style=''>noises</span> <span style=''>We</span> <span style=''>also</span> <span style=''>provide</span> <span style='background-color:rgba(255, 0, 0, 0.36607142857142855);'>theoretical</span> <span style='background-color:rgba(255, 0, 0, 0.36645962732919246);'>guarantees</span> <span style=''>for</span> <span style=''>RKPCA</span> <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>of</span> <span style=''>RKPCA</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3891891891891893);'>challenging</span> <span style=''>because</span> <span style=''>it</span> <span style=''>involves</span> <span style='background-color:rgba(255, 0, 0, 0.7142857142857142);'>nonconvex</span> <span style=''>and</span> <span style=''>indifferentiable</span> <span style=''>problems</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>simultaneously</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>two</span> <span style='background-color:rgba(255, 0, 0, 0.7142857142857142);'>nonconvex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>for</span> <span style=''>RKPCA</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>alternating</span> <span style='background-color:rgba(0, 255, 0, 0.3);'> ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Unsupervised</span> <span style=''>vehicle</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>recognition</span> <span style=''>using</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>incremental</span> <span style=''>reseeding</span> <span style=''>of</span> <span style=''>acoustic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>signatures</span> <br/><br/><span style=''>Vehicle</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>recognition</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>have</span> <span style=''>broad</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <span style=''>ranging</span> <span style=''>from</span> <span style=''>traffic</span> <span style=''>flow</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>management</span> <span style=''>to</span> <span style=''>military</span> <span style=''>target</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>identification</span> <span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>demonstrate</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>unsupervised</span> <span style=''>method</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>automated</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>identification</span> <span style=''>of</span> <span style=''>moving</span> <span style=''>vehicles</span> <span style=''>from</span> <span style=''>roadside</span> <span style=''>audio</span> <span style=''>sensors</span> <span style=''>Using</span> <span style=''>a</span> <span style=''>short</span> <span style=''>time</span> <span style=''>Fourier</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>transform</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>decompose</span> <span style=''>audio</span> <span style=''>signals</span> <span style=''>we</span> <span style=''>treat</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>frequency</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>signature</span> <span style=''>in</span> <span style=''>each</span> <span style=''>time</span> <span style=''>window</span> <span style=''>as</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>individual</span> <span style=''>data</span> <span style=''>point</span> <span style=''>We</span> <span style=''>then</span> <span style=''>use</span> <span style=''>a</span> <span style=''>spectral</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>embedding</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensionality</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>reduction</span> <span style=''>Based</span> <span style=''>on</span> <span style=''>the</span> <span style=''>leading</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>eigenvectors</span> <span style=''>we</span> <span style=''>relate</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>of</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>incremental</span> <span style=''>reseeding</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>to</span> <span style=''>that</span> <span style=''>of</span> <span style=''>spectral</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>We</span> <span style=''>find</span> <span style=''>that</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>incremental</span> <span style=''>reseeding</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>accurately</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>ide ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	automatic (0.07071069633883705)
# 	processing (0.10229720028715003)
# 	architecture (0.08183776022972003)
# 	knowledge (0.1349605168700646)
# 	segmentation (0.07860732232591529)
# 	information (0.250897343862168)
# 	detection (0.12096195262024408)
# 	different (0.25233309404163673)
# 	convolutional (0.12742282842785355)
# 	recognition (0.12885857860732233)
#
# Some Statistics words are:
# 	algorithm (0.38629592850049654)
# 	variables (0.13356504468718966)
# 	stochastic (0.13952333664349553)
# 	estimation (0.16683217477656406)
# 	theoretical (0.1519364448857994)
# 	statistical (0.1519364448857994)
# 	distribution (0.19116186693147963)
# 	dimensional (0.18867924528301888)
# 	inference (0.19910625620655412)
# 	regression (0.176266137040715)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="46f11b61-957b-4510-b423-189f5cb844d3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("46f11b61-957b-4510-b423-189f5cb844d3")) {                    Plotly.newPlot(                        "46f11b61-957b-4510-b423-189f5cb844d3",                        [{"x":["described","dimensional","decisions","structured","independently","marketplaces","maximizing","according","objective","parameters","structure","purchasing","logarithmic","motivated","specifically","customers","regularized","algorithm","characteristics","dimensions","numerical","furthermore","leverages","clairvoyant","likelihood","prevalence","supervised","usefulness","scenarios","experiments","imbalanced","performance","developed","classification","demonstrate","combining","assumptions","practical","distributional","optimization","restrictive","satisfied","generalization","contribute","operating","characteristic","improving","unlabeled","theoretically","constraints","providing","dimension","activation","convergence","complexity","rademacher","efficient","conditioned","algorithms","beneficial","constraint","layerwise","introduce","regularization","properties","representation","effectiveness","consisting","wasserstein","experimental","deconvolutional","generators","adversarial","variables","different","transforms","instability","generative","corresponds","generator","generating","detection","monitoring","approximated","improvement","estimation","estimating","considerably","frequency","important","compressed","substantial","statistically","functions","uncertainty","multivariate","condition","continuous","generated","applications","necessary","discovery","identified","comparisons","particular","bivariate","conventional","causality","identifiability","artificial","sufficient","situations","incrementally","conditions","deformation","framework","efficiency","advantage","alignment","incremental","approaches","alleviate","evaluated","regressors","unconstrained","regression","challenging","personalized","configurations","investigation","crossover","application","distribution","presented","presenting","computational","operators","influences","combinatorial","effective","describes","including","multitask","formalized","available","applicable","improvements","augmentation","complementary","attention","methodology","increases","predictors","distributed","potential","electricity","representative","irregular","unreliable","industrial","significant","commercial","covariate","imbalance","reduction","affective","embeddings","accelerate","meaningful","representations","leveraged","propagation","classifier","expansion","reproducible","compatible","orientation","classifiers","automatically","specialized","embedding","performed","geometric","hyperparameter","algebraic","combination","naturally","nonlinear","appealing","recurrent","themselves","directional","convexity","accelerates","composite","stochastic","techniques","knowledge","stationary","iterations","comparing","especially","associated","principled","architecture","computing","principal","approximation","directions","euclidean","distributions","mechanism","barycenters","adaptation","community","supporting","conducted","dimensionality","extremely","recognition","instantaneous","inference","introduced","beginning","assumption","machinery","producing","alternative","subsequently","inherently","highlights","complicated","confident","sophisticated","limitation","accessible","practitioners","discriminative","contributions","transcripts","innovations","expression","treatments","predictions","functional","consistent","modelling","motivation","challenge","resulting","heterogeneous","additional","connectivity","sensitivity","abundance","exten ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	clairvoyant
# 	bivariate
# 	perturbative
# 	uncollapsed
# 	jackknife
# 	infinitesimal
# 	fragility
# 	byzantine
# 	countable
# 	shattering
# 	heteroscedasticity
# 	depression
# 	deteriorates
# 	overestimate
# 	complemented
# 	missingness
# 	condensed
# 	sparsifies
# 	distributes
# 	quadrature
# Some words which never appear in Statistics papers:
# 	deformation
# 	affective
# 	transcripts
# 	biclustering
# 	biclusters
# 	familiarity
# 	compatibility
# 	detections
# 	authoring
# 	undertake
# 	undecidable
# 	enumerable
# 	tournament
# 	functionalities
# 	translator
# 	deficiency
# 	metaheuristics
# 	metaheuristic
# 	subfields
# 	diversification

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.080240258740182e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7875
